# %% [markdown]
# <a href="https://colab.research.google.com/github/adarshni/CSRModule/blob/mytask/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 pip install babyagi
# Out:
# Collecting babyagi
#   Downloading babyagi-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: Flask>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from babyagi) (3.1.1)
# Collecting sqlalchemy<2.0,>=1.4 (from babyagi)
#   Downloading SQLAlchemy-1.4.54-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.11/dist-packages (from babyagi) (43.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from babyagi) (1.6.1)
# Collecting litellm (from babyagi)
#   Downloading litellm-1.72.3-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (from babyagi) (1.84.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask>=2.0.0->babyagi) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask>=2.0.0->babyagi) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from Flask>=2.0.0->babyagi) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask>=2.0.0->babyagi) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Flask>=2.0.0->babyagi) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from Flask>=2.0.0->babyagi) (3.1.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<2.0,>=1.4->babyagi) (3.2.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography->babyagi) (1.17.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (3.11.15)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (8.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (4.24.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (2.11.5)
# Collecting python-dotenv>=0.2.0 (from litellm->babyagi)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (0.9.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm->babyagi) (0.21.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai->babyagi) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai->babyagi) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai->babyagi) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai->babyagi) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai->babyagi) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai->babyagi) (4.14.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->babyagi) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->babyagi) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->babyagi) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->babyagi) (3.6.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai->babyagi) (3.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography->babyagi) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm->babyagi) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm->babyagi) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm->babyagi) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm->babyagi) (3.22.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->babyagi) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->babyagi) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->babyagi) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm->babyagi) (0.25.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->litellm->babyagi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->litellm->babyagi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->litellm->babyagi) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm->babyagi) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm->babyagi) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm->babyagi) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm->babyagi) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm->babyagi) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm->babyagi) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm->babyagi) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm->babyagi) (1.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm->babyagi) (0.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->babyagi) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->babyagi) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->babyagi) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->babyagi) (6.0.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm->babyagi) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm->babyagi) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm->babyagi) (2.4.0)
# Downloading babyagi-0.1.4-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 4.1 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.54-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.5 MB/s eta 0:00:00
# Downloading litellm-1.72.3-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 83.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: sqlalchemy, python-dotenv, litellm, babyagi
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.41
#     Uninstalling SQLAlchemy-2.0.41:
#       Successfully uninstalled SQLAlchemy-2.0.41
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# Successfully installed babyagi-0.1.4 litellm-1.72.3 python-dotenv-1.1.0 sqlalchemy-1.4.54

# %%
import babyagi

if __name__ == "__main__":
     app = babyagi.create_app('/dashboard')
     app.run(host='0.0.0.0', port=8080)
# Out:
# Using encryption key: 2Sn55Cwxf7JfDCGVmI77XeLSie_EgaKsdaPzUOeMf0U=
# Attempting to load default function packs...
# Registering imports: ['typing']
# Function 'function_added_or_updated' has been added.
# Registering imports: ['os']
# Function 'add_key_wrapper' has been added.
# Function 'get_function_versions_wrapper' has been added.
# Function 'get_function_wrapper' has been added.
# Function 'get_all_functions_wrapper' has been added.
# Function 'activate_function_version_wrapper' has been added.
# Function 'display_functions_wrapper' has been added.
# Registering imports: ['datetime']
# Function 'get_logs_wrapper' has been added.
# Function 'add_trigger_wrapper' has been added.
# Function 'get_all_secret_keys' has been added.
# Function 'get_all_imports_wrapper' has been added.
# Using encryption key: 2Sn55Cwxf7JfDCGVmI77XeLSie_EgaKsdaPzUOeMf0U=
# Registering imports: ['litellm']
# Function gpt_call requires keys: ['openai_api_key']
# Function 'gpt_call' has been added.
# Function 'description_writer' has been added.
# Function 'ai_description_generator' has been added.
# Generating AI description for function: ai_description_generator
# Function 'ai_description_generator' already has a non-empty description.
# Function 'generate_missing_descriptions' has been added.
# Generating AI description for function: generate_missing_descriptions
# Function 'generate_missing_descriptions' already has a non-empty description.
# Registering imports: ['litellm']
# Function embed_input requires keys: ['openai_api_key']
# Function 'embed_input' has been added.
# Generating AI description for function: embed_input
# Function 'embed_input' already has a non-empty description.
# Registering imports: ['os', 'csv']
# Function 'embed_function_description' has been added.
# Generating AI description for function: embed_function_description
# Function 'embed_function_description' already has a non-empty description.
# Registering imports: ['numpy', 'csv', 'sklearn', 'os']
# Function 'find_similar_function' has been added.
# Generating AI description for function: find_similar_function
# Function 'find_similar_function' already has a non-empty description.
# Registering imports: ['os', 'csv']
# Function 'generate_missing_embeddings' has been added.
# Generating AI description for function: generate_missing_embeddings
# Function 'generate_missing_embeddings' already has a non-empty description.
# Function 'choose_function' has been added.
# Generating AI description for function: choose_function
# Function 'choose_function' already has a non-empty description.
# Registering imports: ['os']
# Function 'get_full_directory_contents_cleaned' has been added.
# Generating AI description for function: get_full_directory_contents_cleaned
# Function 'get_full_directory_contents_cleaned' already has a non-empty description.
# Registering imports: ['litellm', 'json']
# Function chat_with_functions requires keys: ['OPENAI_API_KEY']
# Function 'chat_with_functions' has been added.
# Generating AI description for function: chat_with_functions
# Function 'chat_with_functions' already has a non-empty description.
# babyagi/__init__.py loaded
#  * Serving Flask app 'babyagi'
#  * Debug mode: off
# Address already in use
# Port 8080 is in use by another program. Either identify and stop that program, or start the server with a different port.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/werkzeug/serving.py", line 759, in __init__
#     self.server_bind()
#   File "/usr/lib/python3.11/http/server.py", line 136, in server_bind
#     socketserver.TCPServer.server_bind(self)
#   File "/usr/lib/python3.11/socketserver.py", line 472, in server_bind
#     self.socket.bind(self.server_address)
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-715149679>", line 5, in <cell line: 0>
#     app.run(host='0.0.0.0', port=8080)
#   File "/usr/local/lib/python3.11/dist-packages/flask/app.py", line 662, in run
#     run_simple(t.cast(str, host), port, self, **options)
#   File "/usr/local/lib/python3.11/dist-packages/werkzeug/serving.py", line 1093, in run_simple
#     srv = make_server(
#           ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/werkzeug/serving.py", line 930, in make_server
#     return ThreadedWSGIServer(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/werkzeug/serving.py", line 782, in __init__
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1671, in getframeinfo
#     lineno = frame.f_lineno
#              ^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'f_lineno'
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/werkzeug/serving.py in __init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     758             try:
# --> 759                 self.server_bind()
#     760                 self.server_activate()
#
# /usr/lib/python3.11/http/server.py in server_bind(self)
#     135         """Override server_bind to store the server name."""
# --> 136         socketserver.TCPServer.server_bind(self)
#     137         host, port = self.server_address[:2]
#
# /usr/lib/python3.11/socketserver.py in server_bind(self)
#     471             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 472         self.socket.bind(self.server_address)
#     473         self.server_address = self.socket.getsockname()
#
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-3-715149679> in <cell line: 0>()
#       4      app = babyagi.create_app('/dashboard')
# ----> 5      app.run(host='0.0.0.0', port=8080)
#
# /usr/local/lib/python3.11/dist-packages/flask/app.py in run(self, host, port, debug, load_dotenv, **options)
#     661         try:
# --> 662             run_simple(t.cast(str, host), port, self, **options)
#     663         finally:
#
# /usr/local/lib/python3.11/dist-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, exclude_patterns, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#    1092
# -> 1093     srv = make_server(
#    1094         hostname,
#
# /usr/local/lib/python3.11/dist-packages/werkzeug/serving.py in make_server(host, port, app, threaded, processes, request_handler, passthrough_errors, ssl_context, fd)
#     929     if threaded:
# --> 930         return ThreadedWSGIServer(
#     931             host, port, app, request_handler, passthrough_errors, ssl_context, fd=fd
#
# /usr/local/lib/python3.11/dist-packages/werkzeug/serving.py in __init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     781
# --> 782                 sys.exit(1)
#     783             except BaseException:
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2090                     stb = ['An exception has occurred, use %tb to see '
#    2091                            'the full traceback.\n']
# -> 2092                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2093                                                                      value))
#    2094                 else:
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
